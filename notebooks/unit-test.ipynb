# %% [markdown]
# # Unit test

# %% [markdown]
# ## Library

# %%
import sys
sys.path.append("..")

# %%
from omegaconf import OmegaConf
from src.load_data import load_data
from src.make_dataset import make_dataset
from src.make_fold import make_fold

# %% [markdown]
# ## Data

# %%
c = OmegaConf.create(
    {
        "settings": {
            "dirs": {"input": "../../input/petfinder-pawpularity-score/"},
            "debug": True,
            "n_debug_data": 1000,
        },
        "params": {"seed": 440},
    }
)

# %%
train, test, sub = load_data(c)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1000 non-null   object
#  1   Subject Focus  1000 non-null   int64
#  2   Eyes           1000 non-null   int64
#  3   Face           1000 non-null   int64
#  4   Near           1000 non-null   int64
#  5   Action         1000 non-null   int64
#  6   Accessory      1000 non-null   int64
#  7   Group          1000 non-null   int64
#  8   Collage        1000 non-null   int64
#  9   Human          1000 non-null   int64
#  10  Occlusion      1000 non-null   int64
#  11  Info           1000 non-null   int64
#  12  Blur           1000 non-null   int64
#  13  Pawpularity    1000 non-null   int64
# dtypes: int64(13), object(1)
# memory usage: 109.5+ KB

# %%
train
# Out:
#                                    Id  Subject Focus  Eyes  Face  Near  \
# 0    488298fcc3d5775c28a3dd36ac4ab6b2              0     1     1     1
# 1    5b642648d499ec86150548efeec6952c              0     1     1     1
# 2    09ae71fc4eda1e0ae05680d1950bc009              0     1     1     1
# 3    2a2ceac403616985e66a2129ca00becb              0     1     1     1
# 4    0fe420dc155683b1a0f2d4d26c3c136a              0     1     1     1
# ..                                ...            ...   ...   ...   ...
# 995  ff0fda5f289ae858781f9aa093df3970              0     0     0     1
# 996  fc41a54a2247d7e4454a3b9534bef214              0     1     1     1
# 997  eabd3a25caaceca90dd188b434ba8a40              0     1     1     1
# 998  820d945d8f44fb03f8bb277dc67ee31d              0     0     1     0
# 999  5866337e225f9ccaa9c89a0f0209417d              0     1     1     1
#
#      Action  Accessory  Group  Collage  Human  Occlusion  Info  Blur  \
# ...

# %% [markdown]
# ## Fold

# %%
c = OmegaConf.create(
    {
        "params": {"seed": 440, "n_fold": 3},
    }
)

# %%
train = make_fold(c, train)

# %%
print(train.groupby(["fold", "bins"]).size())
# Out:
# fold  bins
# 0     0        17
#       1        41
#       2       100
#       3        71
#       4        42
#       5        22
#       6        16
#       7        10
#       8         4
#       9        11
# 1     0        16
#       1        41
#       2       101
#       3        71
#       4        41
#       5        22
#       6        16
#       7        11
#       8         3
#       9        11
# 2     0        16
#       1        41
#       2       101
#       3        71
#       4        41
#       5        22
#       6        15
#       7        11
#       8         4
#       9        11
# dtype: int64

# %% [markdown]
# ## Dataset
